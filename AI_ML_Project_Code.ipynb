# %% [markdown]
# ### Importing Basic Libraries

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt

import seaborn as sb
import seaborn as sns
from seaborn import heatmap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Importing the Dataset

# %%
dataset = pd.read_csv('MiningProcess_Flotation_Plant_Database.csv', decimal=',')

# %% [markdown]
# ### A Quick Review of the Data

# %% [markdown]
# Show the dataframe

# %%
dataset
# Out:
#                        date  % Iron Feed  % Silica Feed  Starch Flow  \
# 0       2017-03-10 01:00:00        55.20          16.98      3019.53
# 1       2017-03-10 01:00:00        55.20          16.98      3024.41
# 2       2017-03-10 01:00:00        55.20          16.98      3043.46
# 3       2017-03-10 01:00:00        55.20          16.98      3047.36
# 4       2017-03-10 01:00:00        55.20          16.98      3033.69
# ...                     ...          ...            ...          ...
# 737448  2017-09-09 23:00:00        49.75          23.20      2710.94
# 737449  2017-09-09 23:00:00        49.75          23.20      2692.01
# 737450  2017-09-09 23:00:00        49.75          23.20      2692.20
# 737451  2017-09-09 23:00:00        49.75          23.20      1164.12
# 737452  2017-09-09 23:00:00        49.75          23.20      1164.12
#
#         Amina Flow  Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# 0          557.434        395.713     10.06640           1.74000
# 1          563.965        397.383     10.06720           1.74000
# 2          568.054        399.668     10.06800           1.74000
# 3          568.665        397.939     10.06890           1.74000
# 4          558.167        400.254     10.06970           1.74000
# ...            ...            ...          ...               ...
# 737448     441.052        386.570      9.62129           1.65365
# 737449     473.436        384.939      9.62063           1.65352
# 737450     500.488        383.496      9.61874           1.65338
# 737451     491.548        384.976      9.61686           1.65324
# 737452     468.019        384.801      9.61497           1.65310
#
#         Flotation Column 01 Air Flow  Flotation Column 02 Air Flow  ...  \
# 0                            249.214                       253.235  ...
# 1                            249.719                       250.532  ...
# 2                            249.741                       247.874  ...
# 3                            249.917                       254.487  ...
# 4                            250.203                       252.136  ...
# ...                              ...                           ...  ...
# 737448                       302.344                       298.786  ...
# 737449                       303.013                       301.879  ...
# 737450                       303.662                       307.397  ...
# 737451                       302.550                       301.959  ...
# 737452                       300.355                       292.865  ...
#
#         Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# 0                            250.884                    457.396
# 1                            248.994                    451.891
# 2                            248.071                    451.240
# 3                            251.147                    452.441
# 4                            248.928                    452.441
# ...                              ...                        ...
# 737448                       313.695                    392.160
# 737449                       236.700                    401.505
# 737450                       225.879                    408.899
# 737451                       308.115                    405.107
# 737452                       308.115                    413.754
#
#         Flotation Column 02 Level  Flotation Column 03 Level  \
# 0                         432.962                    424.954
# 1                         429.560                    432.939
# 2                         468.927                    434.610
# 3                         458.165                    442.865
# 4                         452.900                    450.523
# ...                           ...                        ...
# 737448                    430.702                    872.008
# 737449                    404.616                    864.409
# 737450                    399.316                    867.598
# 737451                    466.832                    876.591
# 737452                    514.143                    881.323
#
#         Flotation Column 04 Level  Flotation Column 05 Level  \
# 0                         443.558                    502.255
# 1                         448.086                    496.363
# 2                         449.688                    484.411
# 3                         446.210                    471.411
# 4                         453.670                    462.598
# ...                           ...                        ...
# 737448                    418.725                    497.548
# 737449                    418.377                    506.398
# 737450                    419.531                    503.414
# 737451                    407.299                    502.301
# 737452                    378.969                    500.100
#
#         Flotation Column 06 Level  Flotation Column 07 Level  \
# 0                         446.370                    523.344
# 1                         445.922                    498.075
# 2                         447.826                    458.567
# 3                         437.690                    427.669
# 4                         443.682                    425.679
# ...                           ...                        ...
# 737448                    446.357                    416.892
# 737449                    372.995                    426.337
# 737450                    336.035                    433.130
# 737451                    340.844                    433.966
# 737452                    374.354                    441.182
#
#         % Iron Concentrate  % Silica Concentrate
# 0                    66.91                  1.31
# 1                    66.91                  1.31
# 2                    66.91                  1.31
# 3                    66.91                  1.31
# 4                    66.91                  1.31
# ...                    ...                   ...
# 737448               64.27                  1.71
# 737449               64.27                  1.71
# 737450               64.27                  1.71
# 737451               64.27                  1.71
# 737452               64.27                  1.71
#
# [737453 rows x 24 columns]

# %%
dataset.head()
# Out:
#                   date  % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# 0  2017-03-10 01:00:00         55.2          16.98      3019.53     557.434
# 1  2017-03-10 01:00:00         55.2          16.98      3024.41     563.965
# 2  2017-03-10 01:00:00         55.2          16.98      3043.46     568.054
# 3  2017-03-10 01:00:00         55.2          16.98      3047.36     568.665
# 4  2017-03-10 01:00:00         55.2          16.98      3033.69     558.167
#
#    Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 0        395.713      10.0664              1.74                       249.214
# 1        397.383      10.0672              1.74                       249.719
# 2        399.668      10.0680              1.74                       249.741
# 3        397.939      10.0689              1.74                       249.917
# 4        400.254      10.0697              1.74                       250.203
#
#    Flotation Column 02 Air Flow  ...  Flotation Column 07 Air Flow  \
# 0                       253.235  ...                       250.884
# 1                       250.532  ...                       248.994
# 2                       247.874  ...                       248.071
# 3                       254.487  ...                       251.147
# 4                       252.136  ...                       248.928
#
#    Flotation Column 01 Level  Flotation Column 02 Level  \
# 0                    457.396                    432.962
# 1                    451.891                    429.560
# 2                    451.240                    468.927
# 3                    452.441                    458.165
# 4                    452.441                    452.900
#
#    Flotation Column 03 Level  Flotation Column 04 Level  \
# 0                    424.954                    443.558
# 1                    432.939                    448.086
# 2                    434.610                    449.688
# 3                    442.865                    446.210
# 4                    450.523                    453.670
#
#    Flotation Column 05 Level  Flotation Column 06 Level  \
# 0                    502.255                    446.370
# 1                    496.363                    445.922
# 2                    484.411                    447.826
# 3                    471.411                    437.690
# 4                    462.598                    443.682
#
#    Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# 0                    523.344               66.91                  1.31
# 1                    498.075               66.91                  1.31
# 2                    458.567               66.91                  1.31
# 3                    427.669               66.91                  1.31
# 4                    425.679               66.91                  1.31
#
# [5 rows x 24 columns]

# %%
# get the types of each column
dataset.dtypes
# Out:
# date                             object
# % Iron Feed                     float64
# % Silica Feed                   float64
# Starch Flow                     float64
# Amina Flow                      float64
# Ore Pulp Flow                   float64
# Ore Pulp pH                     float64
# Ore Pulp Density                float64
# Flotation Column 01 Air Flow    float64
# Flotation Column 02 Air Flow    float64
# Flotation Column 03 Air Flow    float64
# Flotation Column 04 Air Flow    float64
# Flotation Column 05 Air Flow    float64
# Flotation Column 06 Air Flow    float64
# Flotation Column 07 Air Flow    float64
# Flotation Column 01 Level       float64
# Flotation Column 02 Level       float64
# Flotation Column 03 Level       float64
# Flotation Column 04 Level       float64
# Flotation Column 05 Level       float64
# Flotation Column 06 Level       float64
# Flotation Column 07 Level       float64
# % Iron Concentrate              float64
# % Silica Concentrate            float64
# dtype: object

# %% [markdown]
# Check for missing data

# %%
#check for missing values
dataset.isnull().sum()
# Out:
# date                            0
# % Iron Feed                     0
# % Silica Feed                   0
# Starch Flow                     0
# Amina Flow                      0
# Ore Pulp Flow                   0
# Ore Pulp pH                     0
# Ore Pulp Density                0
# Flotation Column 01 Air Flow    0
# Flotation Column 02 Air Flow    0
# Flotation Column 03 Air Flow    0
# Flotation Column 04 Air Flow    0
# Flotation Column 05 Air Flow    0
# Flotation Column 06 Air Flow    0
# Flotation Column 07 Air Flow    0
# Flotation Column 01 Level       0
# Flotation Column 02 Level       0
# Flotation Column 03 Level       0
# Flotation Column 04 Level       0
# Flotation Column 05 Level       0
# Flotation Column 06 Level       0
# Flotation Column 07 Level       0
# % Iron Concentrate              0
# % Silica Concentrate            0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
dataset.head()
# Out:
#                   date  % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# 0  2017-03-10 01:00:00         55.2          16.98      3019.53     557.434
# 1  2017-03-10 01:00:00         55.2          16.98      3024.41     563.965
# 2  2017-03-10 01:00:00         55.2          16.98      3043.46     568.054
# 3  2017-03-10 01:00:00         55.2          16.98      3047.36     568.665
# 4  2017-03-10 01:00:00         55.2          16.98      3033.69     558.167
#
#    Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 0        395.713      10.0664              1.74                       249.214
# 1        397.383      10.0672              1.74                       249.719
# 2        399.668      10.0680              1.74                       249.741
# 3        397.939      10.0689              1.74                       249.917
# 4        400.254      10.0697              1.74                       250.203
#
#    Flotation Column 02 Air Flow  ...  Flotation Column 07 Air Flow  \
# 0                       253.235  ...                       250.884
# 1                       250.532  ...                       248.994
# 2                       247.874  ...                       248.071
# 3                       254.487  ...                       251.147
# 4                       252.136  ...                       248.928
#
#    Flotation Column 01 Level  Flotation Column 02 Level  \
# 0                    457.396                    432.962
# 1                    451.891                    429.560
# 2                    451.240                    468.927
# 3                    452.441                    458.165
# 4                    452.441                    452.900
#
#    Flotation Column 03 Level  Flotation Column 04 Level  \
# 0                    424.954                    443.558
# 1                    432.939                    448.086
# 2                    434.610                    449.688
# 3                    442.865                    446.210
# 4                    450.523                    453.670
#
#    Flotation Column 05 Level  Flotation Column 06 Level  \
# 0                    502.255                    446.370
# 1                    496.363                    445.922
# 2                    484.411                    447.826
# 3                    471.411                    437.690
# 4                    462.598                    443.682
#
#    Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# 0                    523.344               66.91                  1.31
# 1                    498.075               66.91                  1.31
# 2                    458.567               66.91                  1.31
# 3                    427.669               66.91                  1.31
# 4                    425.679               66.91                  1.31
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Check for Outliers

# %% [markdown]
# Visualize the data to see if there are any outliers

# %%
# create boxplots of each column except % silica concentrate
x = dataset.iloc[:, :-1]
for i in range(0, len(x.columns), 6):
    sns.boxplot(data=x.iloc[:, i:i+6])
    # make the x 
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# Based on the boxplots above, we want to remove outliers from the data.

# %% [markdown]
# ### Check for Correlation

# %% [markdown]
# Here we check for strong correlation between the % of silica column and the other columns.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Adjusted function to exclude non-numeric columns
def plotCorrelationMatrix(dataset):
    # Select only numeric columns
    numeric_data = dataset.select_dtypes(include=[np.number])
    corr_matrix = numeric_data.corr()
    
    # Visualizing the correlation matrix
    plt.figure(figsize=(30, 25))  
    sns.heatmap(corr_matrix, annot=True, lw=0, linecolor='white', cmap='magma', fmt='0.2f')
    plt.title("Correlation Matrix", fontsize=50)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.show()

# Call the function with your dataset
plotCorrelationMatrix(dataset)

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# The date has no impact on the % of silica, so we can drop it.

# %%
dataset.drop(['date'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 dataset.drop(['date'], axis=1, inplace=True)
#
# File c:\applications\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
#    5576     )
#
# File c:\applications\anaconda3\envs\tf\lib\site-packages\pandas\core\generic.py:4785, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4783 for axis, labels in axes.items():
#    4784     if labels is not None:
# -> 4785         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4787 if inplace:
#    4788     self._update_inplace(obj)
#
# File c:\applications\anaconda3\envs\tf\lib\site-packages\pandas\core\generic.py:4827, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4825         new_axis = axis.drop(labels, level=level, errors=errors)
#    4826     else:
# -> 4827         new_axis = axis.drop(labels, errors=errors)
#    4828     indexer = axis.get_indexer(new_axis)
#    4830 # Case for non-unique axis
#    4831 else:
#
# File c:\applications\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['date'] not found in axis"

# %% [markdown]
# ### Remove Outliers

# %% [markdown]
# Remove the outliers we found earlier. We will use the IQR method.

# %%
# remove outliers from all columns
x = dataset.iloc[:, :-1]
for i in range(0, len(x.columns)):
    q1 = dataset.iloc[:, i].quantile(0.25)
    q3 = dataset.iloc[:, i].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - (1.5 * iqr)
    upper_bound = q3 + (1.5 * iqr)
    dataset = dataset[(dataset.iloc[:, i] > lower_bound) & (dataset.iloc[:, i] < upper_bound)]

# # create boxplots of each column except % silica concentrate
x = dataset.iloc[:, :-1]
for i in range(0, len(x.columns), 6):
    sns.boxplot(data=x.iloc[:, i:i+6])
    # make the x
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# ### Remove Correlated Columns

# %% [markdown]
# Define a function to find correlated columns, given a threshold.

# %%
def correlation(df, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = df.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %% [markdown]
# Call the function to find correlated columns.

# %%
x = dataset.iloc[:, :-1]
corr_features = correlation(x, 0.7)
corr_features
# Out:
# {'% Silica Feed',
#  'Flotation Column 02 Air Flow',
#  'Flotation Column 02 Level',
#  'Flotation Column 03 Air Flow',
#  'Flotation Column 03 Level',
#  'Flotation Column 07 Air Flow',
#  'Flotation Column 07 Level'}

# %% [markdown]
# Remove the correlated columns from the dataframe to avoid multicollinearity.

# %%
dataset = dataset.drop(corr_features, axis=1)

# %% [markdown]
# Re plot the correlation matrix.

# %%
plotCorrelationMatrix(dataset)

# %%
dataset.head()
# Out:
#    % Iron Feed  Starch Flow  Amina Flow  Ore Pulp Flow  Ore Pulp pH  \
# 0         55.2      3019.53     557.434        395.713      10.0664
# 1         55.2      3024.41     563.965        397.383      10.0672
# 2         55.2      3043.46     568.054        399.668      10.0680
# 3         55.2      3047.36     568.665        397.939      10.0689
# 4         55.2      3033.69     558.167        400.254      10.0697
#
#    Ore Pulp Density  Flotation Column 01 Air Flow  \
# 0              1.74                       249.214
# 1              1.74                       249.719
# 2              1.74                       249.741
# 3              1.74                       249.917
# 4              1.74                       250.203
#
#    Flotation Column 04 Air Flow  Flotation Column 05 Air Flow  \
# 0                       295.096                         306.4
# 1                       295.096                         306.4
# 2                       295.096                         306.4
# 3                       295.096                         306.4
# 4                       295.096                         306.4
#
#    Flotation Column 06 Air Flow  Flotation Column 01 Level  \
# 0                       250.225                    457.396
# 1                       250.137                    451.891
# 2                       251.345                    451.240
# 3                       250.422                    452.441
# 4                       249.983                    452.441
#
#    Flotation Column 04 Level  Flotation Column 05 Level  \
# 0                    443.558                    502.255
# 1                    448.086                    496.363
# 2                    449.688                    484.411
# 3                    446.210                    471.411
# 4                    453.670                    462.598
#
#    Flotation Column 06 Level  % Iron Concentrate  % Silica Concentrate
# 0                    446.370               66.91                  1.31
# 1                    445.922               66.91                  1.31
# 2                    447.826               66.91                  1.31
# 3                    437.690               66.91                  1.31
# 4                    443.682               66.91                  1.31

# %%
dataset
# Out:
#         % Iron Feed  Starch Flow  Amina Flow  Ore Pulp Flow  Ore Pulp pH  \
# 0             55.20      3019.53     557.434        395.713     10.06640
# 1             55.20      3024.41     563.965        397.383     10.06720
# 2             55.20      3043.46     568.054        399.668     10.06800
# 3             55.20      3047.36     568.665        397.939     10.06890
# 4             55.20      3033.69     558.167        400.254     10.06970
# ...             ...          ...         ...            ...          ...
# 737448        49.75      2710.94     441.052        386.570      9.62129
# 737449        49.75      2692.01     473.436        384.939      9.62063
# 737450        49.75      2692.20     500.488        383.496      9.61874
# 737451        49.75      1164.12     491.548        384.976      9.61686
# 737452        49.75      1164.12     468.019        384.801      9.61497
#
#         Ore Pulp Density  Flotation Column 01 Air Flow  \
# 0                1.74000                       249.214
# 1                1.74000                       249.719
# 2                1.74000                       249.741
# 3                1.74000                       249.917
# 4                1.74000                       250.203
# ...                  ...                           ...
# 737448           1.65365                       302.344
# 737449           1.65352                       303.013
# 737450           1.65338                       303.662
# 737451           1.65324                       302.550
# 737452           1.65310                       300.355
#
#         Flotation Column 04 Air Flow  Flotation Column 05 Air Flow  \
# 0                            295.096                       306.400
# 1                            295.096                       306.400
# 2                            295.096                       306.400
# 3                            295.096                       306.400
# 4                            295.096                       306.400
# ...                              ...                           ...
# 737448                       299.920                       299.623
# 737449                       299.710                       300.465
# 737450                       299.927                       299.707
# 737451                       299.372                       298.819
# 737452                       298.717                       297.395
#
#         Flotation Column 06 Air Flow  Flotation Column 01 Level  \
# 0                            250.225                    457.396
# 1                            250.137                    451.891
# 2                            251.345                    451.240
# 3                            250.422                    452.441
# 4                            249.983                    452.441
# ...                              ...                        ...
# 737448                       346.794                    392.160
# 737449                       330.023                    401.505
# 737450                       329.590                    408.899
# 737451                       351.453                    405.107
# 737452                       362.464                    413.754
#
#         Flotation Column 04 Level  Flotation Column 05 Level  \
# 0                         443.558                    502.255
# 1                         448.086                    496.363
# 2                         449.688                    484.411
# 3                         446.210                    471.411
# 4                         453.670                    462.598
# ...                           ...                        ...
# 737448                    418.725                    497.548
# 737449                    418.377                    506.398
# 737450                    419.531                    503.414
# 737451                    407.299                    502.301
# 737452                    378.969                    500.100
#
#         Flotation Column 06 Level  % Iron Concentrate  % Silica Concentrate
# 0                         446.370               66.91                  1.31
# 1                         445.922               66.91                  1.31
# 2                         447.826               66.91                  1.31
# 3                         437.690               66.91                  1.31
# 4                         443.682               66.91                  1.31
# ...                           ...                 ...                   ...
# 737448                    446.357               64.27                  1.71
# 737449                    372.995               64.27                  1.71
# 737450                    336.035               64.27                  1.71
# 737451                    340.844               64.27                  1.71
# 737452                    374.354               64.27                  1.71
#
# [737453 rows x 16 columns]

# %% [markdown]
# Split the dataset into input and output

# %%
# split into X and y
X = dataset.iloc[:, :-1]
y = dataset.iloc[:, -1]

# %% [markdown]
# ### Feature Scaling

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# ### Splitting the datset into the Training set and Test set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
print(y_train.shape)
print(X_train.shape)
# Out:
# (589962,)
# (589962, 15)

# %% [markdown]
# ### A Quick Check of the Output Data

# %%
y_train = y_train.ravel()
y_train
# Out:
# C:\Users\risha\AppData\Local\Temp\ipykernel_22232\1420269113.py:1: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y_train = y_train.ravel()
# array([1.49      , 2.37      , 2.04      , ..., 3.63431885, 3.14      ,
#        1.48      ])

# %%
print(type(X_train))
print(type(y_train))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Linear Regression Model

# %% [markdown]
# ### Training the Model

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predicting the Test set results

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# Make a random prediction

# %%
y_test = y_test.ravel()
y_test
# Out:
# C:\Users\risha\AppData\Local\Temp\ipykernel_22232\990871753.py:1: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y_test = y_test.ravel()
# array([2.57, 1.77, 2.13, ..., 1.7 , 2.55, 1.33])

# %%
print("The Prediction % Silica =",y_pred[6])
print("The Actual % Silica =",y_test[6])
# Out:
# The Prediction % Silica = 1.6201080904456373
# The Actual % Silica = 1.74

# %% [markdown]
# This is a close prediction to the actual value for the % of silica.

# %% [markdown]
# ### Evaluating the Model Performance

# %%
from sklearn.metrics import r2_score, mean_absolute_error

r2score = r2_score(y_test, y_pred)
print("The R2 Score =", r2score * 100, "%")

rmse = np.sqrt(mean_absolute_error(y_test, y_pred))
print("The Root Mean Squared Error =", rmse * 100 ,"%")
# Out:
# The R2 Score = 67.44997729890011 %
# The Root Mean Squared Error = 70.42945726556479 %

# %% [markdown]
# Measure the accuracy of the model

# %%
y_test = y_test.ravel()
print(type(y_test))
print(y_test.shape)
y_test
# Out:
# <class 'numpy.ndarray'>
# (147491,)
# array([2.57, 1.77, 2.13, ..., 1.7 , 2.55, 1.33])

# %%
print(type(y_pred))
print(y_pred.shape)
y_pred
# Out:
# <class 'numpy.ndarray'>
# (147491,)
# array([2.10722432, 1.32562282, 1.07869072, ..., 1.83186508, 3.5192068 ,
#        1.92208299])

# %% [markdown]
# Measuring the average accuracy of the model

# %%
avg_accuracy = 0
for i in range(len(y_pred)):
    error = abs(y_pred[i] - y_test[i])
    avg_accuracy += 1 - error / y_test[i]


avg_accuracy = avg_accuracy / len(y_pred)
print("The Accuracy of the Model =", round(avg_accuracy, 6) * 100, "%")
# Out:
# The Accuracy of the Model = 75.5675 %

# %% [markdown]
# ### Using the Model to Predict the % of Silica

# %%
x_predict_test = X_test[45]
y_pred_new = regressor.predict(x_predict_test.reshape(1, -1))
print("The Predicted % Silica =", y_pred_new[0], "%")
# Out:
# The Predicted % Silica = 2.0083202272147966 %

# %% [markdown]
# ## Other Models

# %% [markdown]
# ### Lasso Regressor Model

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()
lasso.fit(X_train, y_train)
# Out:
# Lasso()

# %%
predictions = lasso.predict(X_test)

# %% [markdown]
# Make a random prediction

# %%
print("The Prediction % Silica =",predictions[7], "%")
print("The Actual % Silica =",y_test[7], "%")
# Out:
# The Prediction % Silica = 2.3278165308678163 %
# The Actual % Silica = 3.1622099448 %

# %%
r2score = r2_score(y_test, predictions)
print("The R2 Score =", r2score)

error = np.sqrt(mean_absolute_error(y_test, predictions))
print("The Mean Squared Error =", error)
# Out:
# The R2 Score = -2.2059210165625842e-05
# The Mean Squared Error = 0.9550522296782258

# %% [markdown]
# ### Stochastic Gradient Descent Regressor Model

# %%
from sklearn.linear_model import SGDRegressor
sgd = SGDRegressor()
sgd.fit(X_train, y_train)
# Out:
# SGDRegressor()

# %%
prediction = sgd.predict(X_test)

# %%
print("The Prediction % Silica =",predictions[7], "%")
print("The Actual % Silica =",y_test[7], "%")
# Out:
# The Prediction % Silica = 2.3278165308678163 %
# The Actual % Silica = 3.1622099448 %

# %%
r2score = r2_score(y_test, predictions)
print("The R2 Score =", r2score)

error = np.sqrt(mean_absolute_error(y_test, predictions))
print("The Mean Squared Error =", error)
# Out:
# The R2 Score = -2.2059210165625842e-05
# The Mean Squared Error = 0.9550522296782258
